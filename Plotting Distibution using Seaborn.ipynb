# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Market=pd.read_csv("D:/MBA/SEM 2/Python/Datasets/market_fact.csv")

# %%
Market
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id      Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818   136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818    42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818  4233.1500      0.08
# ...        ...      ...       ...        ...        ...       ...
# 8394  Ord_5353   Prod_4  SHP_7479  Cust_1798  2841.4395      0.08
# 8395  Ord_5411   Prod_6  SHP_7555  Cust_1798   127.1600      0.10
# 8396  Ord_5388   Prod_6  SHP_7524  Cust_1798   243.0500      0.02
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.8700      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.6900      0.00
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 0                 23   -30.51           3.60                 0.56
# ...

# %% [markdown]
# #### Histogram

# %%
plt.hist(Market['Sales'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### To view all data in Histogram

# %%
plt.hist(Market['Sales'])
plt.yscale('log')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Scatterplot

# %%
plt.scatter(Market['Sales'],Market['Profit'])
plt.show()

# %% [markdown]
# #### To view the density graph on the histogram

# %%
sns.distplot(Market['Shipping_Cost'])
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_10224\914029271.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Market['Shipping_Cost'])

# %% [markdown]
# #### To include rug

# %%
sns.distplot(Market['Shipping_Cost'][:200],rug = True)
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_10224\818000191.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Market['Shipping_Cost'][:200],rug = True)

# %% [markdown]
# #### To create density plot alone

# %%
sns.distplot(Market['Sales'],hist=False)
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_10224\948655566.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Market['Sales'],hist=False)

# %%
plt.subplot(2,2,1)
plt.title('Sales')
sns.distplot(Market['Sales'])

plt.subplot(2,2,2)
plt.title('Profit')
sns.distplot(Market['Profit'])



plt.subplot(2,2,3)
plt.title('Order_Quantity')
sns.distplot(Market['Order_Quantity'])

plt.subplot(2,2,4)
plt.title('Shipping_Cost')
sns.distplot(Market['Shipping_Cost'])

plt.tight_layout()

plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_10224\3090762712.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Market['Sales'])
# C:\Users\admin\AppData\Local\Temp\ipykernel_10224\3090762712.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Market['Profit'])
# ...

# %% [markdown]
# #### Bxplot

# %%
sns.boxplot(Market['Order_Quantity'])
plt.title('Order Quantity')
plt.show()

# %% [markdown]
# #### To change axis into horizontal

# %%
sns.boxplot(x=Market['Order_Quantity'])
plt.title('Order Quantity')
plt.show()

# %% [markdown]
# #### Visualizing Bivariate Distribution

# %%
sns.jointplot(x='Sales',y='Profit',data=Market)
plt.show()

# %% [markdown]
# #### Filtering the dataset to have better view

# %%
Market1 = Market[(Market.Profit < 10000) & (Market.Sales < 20000)]

sns.jointplot(x='Sales',y='Profit',data=Market1)
plt.show()

# %%
Market2 = Market[(Market.Profit < 100) & (Market.Profit > -100) & (Market.Sales < 200)]

sns.jointplot(x='Sales',y='Profit',data=Market2,kind="hex",color="g")
plt.show()
